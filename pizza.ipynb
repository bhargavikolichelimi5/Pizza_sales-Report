# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
df=pd.read_csv("D:\pizza_sales.csv")
#pd.set_option("display.max_rows", None)
df
# Out:
#        pizza_id  order_id  pizza_name_id  quantity  order_date order_time  \
# 0             1         1     hawaiian_m         1  01-01-2015   11:38:36
# 1             2         2  classic_dlx_m         1  01-01-2015   11:57:40
# 2             3         2  five_cheese_l         1  01-01-2015   11:57:40
# 3             4         2    ital_supr_l         1  01-01-2015   11:57:40
# 4             5         2     mexicana_m         1  01-01-2015   11:57:40
# ...         ...       ...            ...       ...         ...        ...
# 48615     48616     21348  ckn_alfredo_m         1  31-12-2015   21:23:10
# 48616     48617     21348  four_cheese_l         1  31-12-2015   21:23:10
# 48617     48618     21348   napolitana_s         1  31-12-2015   21:23:10
# 48618     48619     21349     mexicana_l         1  31-12-2015   22:09:54
# 48619     48620     21350      bbq_ckn_s         1  31-12-2015   23:02:05
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %%
print(df.ndim)
print(df.size)
print(df.dtypes)
# Out:
# 2
# 583440
# pizza_id               int64
# order_id               int64
# pizza_name_id         object
# quantity               int64
# order_date            object
# order_time            object
# unit_price           float64
# total_price          float64
# pizza_size            object
# pizza_category        object
# pizza_ingredients     object
# pizza_name            object
# dtype: object

# %%
df.shape
# Out:
# (48620, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_name_id      48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  object
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.5+ MB

# %%
df.columns
df.keys()
# Out:
# Index(['pizza_id', 'order_id', 'pizza_name_id', 'quantity', 'order_date',
#        'order_time', 'unit_price', 'total_price', 'pizza_size',
#        'pizza_category', 'pizza_ingredients', 'pizza_name'],
#       dtype='object')

# %%
print(df["pizza_category"].describe())
# Out:
# count       48620
# unique          4
# top       Classic
# freq        14579
# Name: pizza_category, dtype: object

# %%
print(df["pizza_ingredients"].describe())
# Out:
# count                                                 48620
# unique                                                   32
# top       Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# freq                                                   2416
# Name: pizza_ingredients, dtype: object

# %%
print(df["quantity"].describe())
# Out:
# count    48620.000000
# mean         1.019622
# std          0.143077
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          4.000000
# Name: quantity, dtype: float64

# %%
print(df["pizza_size"].describe())
# Out:
# count     48620
# unique        5
# top           L
# freq      18526
# Name: pizza_size, dtype: object

# %%
print(df["pizza_id"].describe())
# Out:
# count    48620.000000
# mean     24310.500000
# std      14035.529381
# min          1.000000
# 25%      12155.750000
# 50%      24310.500000
# 75%      36465.250000
# max      48620.000000
# Name: pizza_id, dtype: float64

# %%
print(df["order_id"].describe())
# Out:
# count    48620.000000
# mean     10701.479761
# std       6180.119770
# min          1.000000
# 25%       5337.000000
# 50%      10682.500000
# 75%      16100.000000
# max      21350.000000
# Name: order_id, dtype: float64

# %%
print(df["total_price"].describe())
# Out:
# count    48620.000000
# mean        16.821474
# std          4.437398
# min          9.750000
# 25%         12.750000
# 50%         16.500000
# 75%         20.500000
# max         83.000000
# Name: total_price, dtype: float64

# %%
print(df["order_date"].describe())
# Out:
# count          48620
# unique           358
# top       26-11-2015
# freq             261
# Name: order_date, dtype: object

# %%
countinuous=["pizza_id","order_id","unit_price","total_price"]
print(df[countinuous].describe())
print(df[countinuous].skew())
# Out:
#            pizza_id      order_id    unit_price   total_price
# count  48620.000000  48620.000000  48620.000000  48620.000000
# mean   24310.500000  10701.479761     16.494132     16.821474
# std    14035.529381   6180.119770      3.621789      4.437398
# min        1.000000      1.000000      9.750000      9.750000
# 25%    12155.750000   5337.000000     12.750000     12.750000
# 50%    24310.500000  10682.500000     16.500000     16.500000
# 75%    36465.250000  16100.000000     20.250000     20.500000
# max    48620.000000  21350.000000     35.950000     83.000000
# pizza_id       0.000000
# order_id      -0.002947
# unit_price     0.127419
# total_price    1.732856
# dtype: float64

# %%
categorical=["pizza_name_id","pizza_size","pizza_category","pizza_name"]
print(df[categorical].nunique())
print(df[categorical].value_counts())
print(df["pizza_category"].unique())
print(df["pizza_size"].unique())
# Out:
# pizza_name_id     91
# pizza_size         5
# pizza_category     4
# pizza_name        32
# dtype: int64
# pizza_name_id   pizza_size  pizza_category  pizza_name
# big_meat_s      S           Classic         The Big Meat Pizza           1811
# thai_ckn_l      L           Chicken         The Thai Chicken Pizza       1365
# five_cheese_l   L           Veggie          The Five Cheese Pizza        1359
# four_cheese_l   L           Veggie          The Four Cheese Pizza        1273
# classic_dlx_m   M           Classic         The Classic Deluxe Pizza     1159
#                                                                          ...
# mexicana_s      S           Veggie          The Mexicana Pizza            160
# calabrese_s     S           Supreme         The Calabrese Pizza            99
# ckn_alfredo_s   S           Chicken         The Chicken Alfredo Pizza      96
# green_garden_l  L           Veggie          The Green Garden Pizza         94
# ...

# %%
import math
print(df['unit_price'].mean())
print(df['unit_price'].median())
print(df['unit_price'].mode())
print(df['unit_price'].var())
print(df['unit_price'].std())
# Out:
# 16.494132044426163
# 16.5
# 0    20.75
# Name: unit_price, dtype: float64
# 13.117356709769059
# 3.6217891586575077

# %%
print(df['total_price'].mean())
print(df['total_price'].median())
print(df['total_price'].mode())
print(df['total_price'].var())
print(df['total_price'].std())
# Out:
# 16.821473673385437
# 16.5
# 0    20.75
# Name: total_price, dtype: float64
# 19.69049729346722
# 4.4373975811805755

# %%
print(df['quantity'].mean())
print(df['quantity'].median())
print(df['quantity'].mode())
print(df['quantity'].var())
print(df['quantity'].std())
# Out:
# 1.0196215549156726
# 1.0
# 0    1
# Name: quantity, dtype: int64
# 0.02047103059731733
# 0.14307700932475953

# %%
plt.boxplot(df["total_price"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16f54a6d090>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16f54a6f9d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16f5491b610>],
#  'medians': [<matplotlib.lines.Line2D at 0x16f54a6fc50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16f54a6fd90>],
#  'means': []}

# %%
sns.histplot(x=df["pizza_id"],bins=3)
# Out:
# <Axes: xlabel='pizza_id', ylabel='Count'>

# %%
sns.histplot(x=df["unit_price"],bins=10)
# Out:
# <Axes: xlabel='unit_price', ylabel='Count'>

# %%
sns.histplot(x=df["total_price"],bins=20)
# Out:
# <Axes: xlabel='total_price', ylabel='Count'>

# %%
sns.kdeplot(x=df["total_price"])
# Out:
# <Axes: xlabel='total_price', ylabel='Density'>

# %%
sns.histplot(x=df["total_price"],bins=5,kde=True)
# Out:
# <Axes: xlabel='total_price', ylabel='Count'>

# %%
sns.boxplot(df["quantity"])
# Out:
# <Axes: ylabel='quantity'>

# %%
sns.kdeplot(x=df["quantity"])
# Out:
# <Axes: xlabel='quantity', ylabel='Density'>

# %%
sns.histplot(x=df["quantity"],bins=40,kde=True)
# Out:
# <Axes: xlabel='quantity', ylabel='Count'>

# %%
sns.boxplot(x=df["pizza_id"])
# Out:
# <Axes: xlabel='pizza_id'>

# %%
sns.histplot(x=df["pizza_id"],bins=10)
# Out:
# <Axes: xlabel='pizza_id', ylabel='Count'>

# %%
sns.kdeplot(x=df["pizza_id"])
# Out:
# <Axes: xlabel='pizza_id', ylabel='Density'>

# %%
sns.histplot(x=df["pizza_id"],bins=40,kde=True)
# Out:
# <Axes: xlabel='pizza_id', ylabel='Count'>

# %%
sns.countplot(x=df["quantity"])
# Out:
# <Axes: xlabel='quantity', ylabel='count'>

# %%
plt.scatter(x=df["quantity"],y=df["total_price"],marker='.',color="red")
plt.show()

# %%
plt.plot(df["quantity"],df["total_price"],marker='*')
plt.show()

# %%
plt.pie(x=df["pizza_category"].value_counts(),labels=df["pizza_category"].value_counts().index,autopct="%0.1f%%")
plt.show()

# %%
plt.pie(x=df["pizza_size"].value_counts(),labels=df["pizza_size"].value_counts().index,autopct="%0.1f%%")
plt.show()
